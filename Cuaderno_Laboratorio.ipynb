# %%
from bs4 import BeautifulSoup as bs
import pandas as pd

html = open("prueba.html", encoding=None).read()
soup = bs(html, "html.parser")

resultados = []

for fila in soup.select("tr.grid-row"):
    dato = {}
    for celda in fila.select("td.grid-cell"):
        campo = celda.get("data-name")
        valor = celda.get_text(strip= True)
        dato[campo] = valor
    resultados.append(dato)

orden = {}

for fila in soup.select("h4.modal-title"):
    dato2 = []
    valor = fila.get_text(strip=True)
    dato2 = valor.split()
    orden_num = dato2[3]
    orden["Numero Orden"] = orden_num

# dato2.append(valor)

df = pd.DataFrame(resultados)

# %%
print(df)
# Out:
#    Rechazo                                         Estudio  \
# 0           ELECTROLITOS PLASMATICOS (cloro,sodio,potasio)
# 1           ELECTROLITOS PLASMATICOS (cloro,sodio,potasio)
# 2           ELECTROLITOS PLASMATICOS (cloro,sodio,potasio)
# 3                                           GASES ARTERIAL
# 4                                           GASES ARTERIAL
# 5                                           GASES ARTERIAL
# 6                                           GASES ARTERIAL
# 7                                           GASES ARTERIAL
# 8                                           GASES ARTERIAL
# 9                                           GASES ARTERIAL
# 10                                          GASES ARTERIAL
#
#                                Prueba Resultado    ValReferencia  \
# 0                               SODIO       138    136   /   145
# 1                             POTASIO       3.5    3.5   /   4.5
# 2                               CLORO       106     98   /   107
# 3   SATURACION DE 02 CALCULADA (sO2c)      97.8        0   /   0
# 4                EXCESO DE BASE (BEb)      -2.7        0   /   2
# 5                  BICARBONATO (HCO3)      21.0        0   /   0
# 6                    C02 TOTAL (TCO2)      22.0        0   /   0
# 7                                 pO2     101.9      80   /   95
# 8                                  pH      7.42  7.35   /   7.45
# 9                                pCO2      33.5      35   /   45
# 10                      CALCIO IONICO      1.03        0   /   0
#
#        FechaValidacion      Estado Nota
# 0   08-02-2026 5:50:25  DISPONIBLE
# 1   08-02-2026 5:50:25  DISPONIBLE
# 2   08-02-2026 5:50:25  DISPONIBLE
# 3   08-02-2026 5:38:41  DISPONIBLE
# 4   08-02-2026 5:38:41  DISPONIBLE
# 5   08-02-2026 5:38:41  DISPONIBLE
# 6   08-02-2026 5:38:41  DISPONIBLE
# 7   08-02-2026 5:38:41  DISPONIBLE
# 8   08-02-2026 5:38:41  DISPONIBLE
# 9   08-02-2026 5:38:41  DISPONIBLE
# 10  08-02-2026 5:38:41  DISPONIBLE

# %%
df.head(10)
# Out:
#   Rechazo                                         Estudio  \
# 0          ELECTROLITOS PLASMATICOS (cloro,sodio,potasio)
# 1          ELECTROLITOS PLASMATICOS (cloro,sodio,potasio)
# 2          ELECTROLITOS PLASMATICOS (cloro,sodio,potasio)
# 3                                          GASES ARTERIAL
# 4                                          GASES ARTERIAL
# 5                                          GASES ARTERIAL
# 6                                          GASES ARTERIAL
# 7                                          GASES ARTERIAL
# 8                                          GASES ARTERIAL
# 9                                          GASES ARTERIAL
#
#                               Prueba Resultado    ValReferencia  \
# 0                              SODIO       138    136   /   145
# 1                            POTASIO       3.5    3.5   /   4.5
# 2                              CLORO       106     98   /   107
# 3  SATURACION DE 02 CALCULADA (sO2c)      97.8        0   /   0
# 4               EXCESO DE BASE (BEb)      -2.7        0   /   2
# 5                 BICARBONATO (HCO3)      21.0        0   /   0
# 6                   C02 TOTAL (TCO2)      22.0        0   /   0
# 7                                pO2     101.9      80   /   95
# 8                                 pH      7.42  7.35   /   7.45
# 9                               pCO2      33.5      35   /   45
#
#       FechaValidacion      Estado Nota
# 0  08-02-2026 5:50:25  DISPONIBLE
# 1  08-02-2026 5:50:25  DISPONIBLE
# 2  08-02-2026 5:50:25  DISPONIBLE
# 3  08-02-2026 5:38:41  DISPONIBLE
# 4  08-02-2026 5:38:41  DISPONIBLE
# 5  08-02-2026 5:38:41  DISPONIBLE
# 6  08-02-2026 5:38:41  DISPONIBLE
# 7  08-02-2026 5:38:41  DISPONIBLE
# 8  08-02-2026 5:38:41  DISPONIBLE
# 9  08-02-2026 5:38:41  DISPONIBLE

# %%
orden_num
orden
# Out:
# {'Numero Orden': '20933069'}
